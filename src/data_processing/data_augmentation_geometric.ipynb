# %% [markdown]
# # Image augmentation with geometric transformations
#
# This notebook applies geometric transformations to images in the given directory
#
# ## Requirements
# - the directory is structured in `images/` and `labels/`
# - the images are in `.jpg` format
# - the labels are in `.txt` format with YOLO format annotations
# - for each training image, generate 3 outputs
#
#
# ## Preprocessing
# - Stretch to `pixels` x `pixels`
#
# ## Augmentation
# - Rotate (90, -90 or 180)
# - Flip (horizontal or vertical)
# - Brightness ([+`deltaBright`%, -`deltaBright`%])

# %%
# Config
PIXELS = 320
DELTA_BRIGHT = 50
OUTPUTS = 3

# %%
# Image transformations
from PIL import Image, ImageEnhance
import random
import os

def resize_image(image, pixels):
    return image.resize((pixels, pixels))

# resize the annotations of an image to resize as a square with length `pixels`
def resize_annotations(image, annotations, pixels):
    width, height = image.size
    new_width = pixels
    new_height = pixels

    # Calculate the scaling factors
    x_scale = new_width / width
    y_scale = new_height / height

    # Resize annotations
    resized_annotations = []
    for annotation in annotations:
        class_id, x_center, y_center, width, height = annotation
        x_center *= x_scale
        y_center *= y_scale
        width *= x_scale
        height *= y_scale
        resized_annotations.append((class_id, x_center, y_center, width, height))

    return annotations

def rotate_image(image, angle):
    return image.rotate(angle, expand=True)

def rotate_annotations(annotations, angle):
    # angle is only 90, -90 or 180
    rotated_annotations = []
    for annotation in annotations:
        class_id, x_center, y_center, width, height = annotation
        if angle == 90:
            new_x_center = y_center
            new_y_center = 1 - x_center
            new_width = height
            new_height = width
        elif angle == -90:
            new_x_center = 1 - y_center
            new_y_center = x_center
            new_width = height
            new_height = width
        elif angle == 180:
            new_x_center = 1 - x_center
            new_y_center = 1 - y_center
            new_width = width
            new_height = height
        else:
            raise ValueError("Angle must be 90, -90 or 180 degrees")
        
        rotated_annotations.append((class_id, new_x_center, new_y_center, new_width, new_height))
    return rotated_annotations

def flip_image(image, direction):
    if direction == 'horizontal':
        return image.transpose(Image.FLIP_LEFT_RIGHT)
    elif direction == 'vertical':
        return image.transpose(Image.FLIP_TOP_BOTTOM)
    else:
        raise ValueError("Direction must be 'horizontal' or 'vertical'")
    
def flip_annotations(annotations, direction):
    flipped_annotations = []
    for annotation in annotations:
        class_id, x_center, y_center, width, height = annotation
        if direction == 'horizontal':
            new_x_center = 1 - x_center
            new_y_center = y_center
        elif direction == 'vertical':
            new_x_center = x_center
            new_y_center = 1 - y_center
        else:
            raise ValueError("Direction must be 'horizontal' or 'vertical'")
        
        flipped_annotations.append((class_id, new_x_center, new_y_center, width, height))
    return flipped_annotations

def adjust_brightness(image, delta):
    # return the image with brightness adjusted by `delta` percent
    enhancer = ImageEnhance.Brightness(image)
    factor = 1 + delta / 100.0  # Convert percentage to a factor
    return enhancer.enhance(factor)

def process_image(image, annotations, pixels, angle, flip_direction, brightness_delta):
    # Resize the image
    resized_image = resize_image(image, pixels)
    resized_annotations = resize_annotations(image, annotations, pixels)

    # Rotate the image
    if angle is not None:
        rotated_image = rotate_image(resized_image, angle)
        rotated_annotations = rotate_annotations(resized_annotations, angle)
    else:
        rotated_image = resized_image
        rotated_annotations = resized_annotations

    # Flip the image
    if flip_direction is not None:
        flipped_image = flip_image(rotated_image, flip_direction)
        flipped_annotations = flip_annotations(rotated_annotations, flip_direction)
    else:
        flipped_image = rotated_image
        flipped_annotations = rotated_annotations

    # Adjust brightness
    if brightness_delta is not None:
        final_image = adjust_brightness(flipped_image, brightness_delta)
    else:
        final_image = flipped_image

    return final_image, flipped_annotations

def transform_image(image, annotations):
    output = {
        'images': [],
        'annotations': [],
        'transformations': []
    }

    pixels = PIXELS

    # Add the original image and annotations resized
    resized_image = resize_image(image, pixels)
    resized_annotations = resize_annotations(image, annotations, pixels)
    output['images'].append(resized_image)
    output['annotations'].append(resized_annotations)
    output['transformations'].append(('N', 'N', 'N'))  # Original image has no transformations

    # Prepare to generate transformations
    transformations = [
        ('N', 'N', 'N')  # Original image transformation
    ]
    # Generate three transformations randomly selected and check if they are all different
    angles = [90, -90, 180, None]  # None means no rotation
    flip_directions = ['horizontal', 'vertical', None]  # None means no flip
    brightness_max = [DELTA_BRIGHT, None]
    while len(transformations) < OUTPUTS:
        angle = random.choice(angles)
        flip_direction = random.choice(flip_directions)
        brightness_delta = random.choice(brightness_max)
        if brightness_delta is not None:
            # select a number between -DELTA_BRIGHT and DELTA_BRIGHT
            brightness_delta = round(random.uniform(-DELTA_BRIGHT, DELTA_BRIGHT), 2)

        # Check if the transformation is already in the list
        transformation = (angle, flip_direction, brightness_delta)
        if transformation not in transformations:
            transformations.append(transformation)
            final_image, final_annotations = process_image(image, annotations, pixels, angle, flip_direction, brightness_delta)
            output['images'].append(final_image)
            output['annotations'].append(final_annotations)
            # tranform None into N string
            angle = angle if angle is not None else 'N'
            flip_direction = flip_direction if flip_direction is not None else 'N'
            brightness_delta = brightness_delta if brightness_delta is not None else 'N'
            output['transformations'].append((angle, flip_direction, brightness_delta))
    
    return output

def load_transform_store(src_dir, image_name, out_dir):
    """
    Load an image and its annotations, apply transformations, and store the results.
    
    :param src_dir: Source directory containing images and labels
    :param image_name: Name of the image file with .jpg extension (without path)
    :param out_dir: Output directory to store transformed images and annotations
    :return: None
    """
    # Load the image
    image_path = os.path.join(src_dir, 'images', image_name)
    image = Image.open(image_path)

    # Load the annotations
    label_name = image_name.replace('.jpg', '.txt')
    label_path = os.path.join(src_dir, 'labels', label_name)
    with open(label_path, 'r') as f:
        annotations = [tuple(map(float, line.strip().split()[:5])) for line in f.readlines()]

    # Transform the image and annotations
    output = transform_image(image, annotations)

    # Store the results
    for i, (final_image, final_annotations, transformation) in enumerate(zip(output['images'], output['annotations'], output['transformations'])):
        # Save the image
        angle, flip_direction, brightness_delta = transformation
        if angle == 'N' and flip_direction == 'N' and brightness_delta == 'N':
            suffix = ''
        else:
            suffix = f"_{angle}_{flip_direction}_{brightness_delta}".replace(".", ",")
        final_image_name = image_name.replace('.jpg', f'{suffix}.jpg')
        final_image_path = os.path.join(out_dir, 'images', final_image_name)
        final_image.save(final_image_path)

        # Save the annotations
        final_label_name = final_image_name.replace('.jpg', '.txt')
        final_label_path = os.path.join(out_dir, 'labels', final_label_name)
        with open(final_label_path, 'w') as f:
            for annotation in final_annotations:
                class_id, x_center, y_center, width, height = annotation
                f.write(f"{int(class_id)} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")
        print(f"Transformed image saved as: {final_image_path}")
        print(f"Transformed annotations saved as: {final_label_path}")

# %%
DATASETS_DIR = "../../datasets/extracted"

DATASET_SRC = "RoboFlow-2"
DATASET_DEST = DATASET_SRC + "-augmented"
DATASET_SET_FOLDER = "train"

src_dir = os.path.join(DATASETS_DIR, DATASET_SRC, DATASET_SET_FOLDER)
out_dir = os.path.join(DATASETS_DIR, DATASET_DEST, DATASET_SET_FOLDER)

# %%
# Remove the output directory if it exists
if os.path.exists(out_dir):
    print(f"Removing existing output directory: {out_dir}")
    for root, dirs, files in os.walk(out_dir, topdown=False):
        for name in files:
            os.remove(os.path.join(root, name))
        for name in dirs:
            os.rmdir(os.path.join(root, name))
    os.rmdir(out_dir)

# Create output directories if they do not exist
os.makedirs(os.path.join(out_dir, 'images'), exist_ok=True)
os.makedirs(os.path.join(out_dir, 'labels'), exist_ok=True)

# Process each image in the source directory
for image_name in os.listdir(os.path.join(src_dir, 'images')):
    if image_name.endswith('.jpg'):
        print(f"Processing image: {image_name}")
        load_transform_store(src_dir, image_name, out_dir)
    else:
        print(f"Skipping non-image file: {image_name}")
print("Data augmentation completed.")
# Out:
# Removing existing output directory: ../../datasets/extracted/RoboFlow-2-augmented/train
# Processing image: 847963f0-R_3018_jpg.rf.ff9d79319ee5c2070abfd5a97222334c.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/847963f0-R_3018_jpg.rf.ff9d79319ee5c2070abfd5a97222334c.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/847963f0-R_3018_jpg.rf.ff9d79319ee5c2070abfd5a97222334c.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/847963f0-R_3018_jpg.rf.ff9d79319ee5c2070abfd5a97222334c_90_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/847963f0-R_3018_jpg.rf.ff9d79319ee5c2070abfd5a97222334c_90_vertical_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/847963f0-R_3018_jpg.rf.ff9d79319ee5c2070abfd5a97222334c_-90_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/847963f0-R_3018_jpg.rf.ff9d79319ee5c2070abfd5a97222334c_-90_N_N.txt
# Processing image: eaef66cd-AluCan89_jpg.rf.27670f9c17e5e5c7048484ee5c26ce5b.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/eaef66cd-AluCan89_jpg.rf.27670f9c17e5e5c7048484ee5c26ce5b.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/eaef66cd-AluCan89_jpg.rf.27670f9c17e5e5c7048484ee5c26ce5b.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/eaef66cd-AluCan89_jpg.rf.27670f9c17e5e5c7048484ee5c26ce5b_-90_horizontal_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/eaef66cd-AluCan89_jpg.rf.27670f9c17e5e5c7048484ee5c26ce5b_-90_horizontal_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/eaef66cd-AluCan89_jpg.rf.27670f9c17e5e5c7048484ee5c26ce5b_N_N_18,44.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/eaef66cd-AluCan89_jpg.rf.27670f9c17e5e5c7048484ee5c26ce5b_N_N_18,44.txt
# Processing image: 4fb13b15-R_2732_jpg.rf.6782ea068397ad10b1ffe18f03473a66.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/4fb13b15-R_2732_jpg.rf.6782ea068397ad10b1ffe18f03473a66.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/4fb13b15-R_2732_jpg.rf.6782ea068397ad10b1ffe18f03473a66.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/4fb13b15-R_2732_jpg.rf.6782ea068397ad10b1ffe18f03473a66_N_horizontal_-13,16.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/4fb13b15-R_2732_jpg.rf.6782ea068397ad10b1ffe18f03473a66_N_horizontal_-13,16.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/4fb13b15-R_2732_jpg.rf.6782ea068397ad10b1ffe18f03473a66_180_N_17,65.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/4fb13b15-R_2732_jpg.rf.6782ea068397ad10b1ffe18f03473a66_180_N_17,65.txt
# Processing image: a729cb37-R_132_jpg.rf.6e7346c8bc7f0c5afe3851c050005d5e.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a729cb37-R_132_jpg.rf.6e7346c8bc7f0c5afe3851c050005d5e.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a729cb37-R_132_jpg.rf.6e7346c8bc7f0c5afe3851c050005d5e.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a729cb37-R_132_jpg.rf.6e7346c8bc7f0c5afe3851c050005d5e_180_N_-13,33.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a729cb37-R_132_jpg.rf.6e7346c8bc7f0c5afe3851c050005d5e_180_N_-13,33.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a729cb37-R_132_jpg.rf.6e7346c8bc7f0c5afe3851c050005d5e_N_N_17,06.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a729cb37-R_132_jpg.rf.6e7346c8bc7f0c5afe3851c050005d5e_N_N_17,06.txt
# Processing image: fe3afdf2-R_1662_jpg.rf.8ead6f4ebcdad7ddd145af3d7826ccb9.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/fe3afdf2-R_1662_jpg.rf.8ead6f4ebcdad7ddd145af3d7826ccb9.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/fe3afdf2-R_1662_jpg.rf.8ead6f4ebcdad7ddd145af3d7826ccb9.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/fe3afdf2-R_1662_jpg.rf.8ead6f4ebcdad7ddd145af3d7826ccb9_N_vertical_24,42.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/fe3afdf2-R_1662_jpg.rf.8ead6f4ebcdad7ddd145af3d7826ccb9_N_vertical_24,42.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/fe3afdf2-R_1662_jpg.rf.8ead6f4ebcdad7ddd145af3d7826ccb9_90_vertical_-11,95.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/fe3afdf2-R_1662_jpg.rf.8ead6f4ebcdad7ddd145af3d7826ccb9_90_vertical_-11,95.txt
# Processing image: c77e1fcc-R_2286_jpg.rf.8480e01264b9eecb55783ab7d8dfb221.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/c77e1fcc-R_2286_jpg.rf.8480e01264b9eecb55783ab7d8dfb221.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/c77e1fcc-R_2286_jpg.rf.8480e01264b9eecb55783ab7d8dfb221.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/c77e1fcc-R_2286_jpg.rf.8480e01264b9eecb55783ab7d8dfb221_-90_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/c77e1fcc-R_2286_jpg.rf.8480e01264b9eecb55783ab7d8dfb221_-90_N_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/c77e1fcc-R_2286_jpg.rf.8480e01264b9eecb55783ab7d8dfb221_90_N_45,53.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/c77e1fcc-R_2286_jpg.rf.8480e01264b9eecb55783ab7d8dfb221_90_N_45,53.txt
# Processing image: a02951a8-R_3480_jpg.rf.60ef8b9e04f9ad38560550afc8397cda.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a02951a8-R_3480_jpg.rf.60ef8b9e04f9ad38560550afc8397cda.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a02951a8-R_3480_jpg.rf.60ef8b9e04f9ad38560550afc8397cda.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a02951a8-R_3480_jpg.rf.60ef8b9e04f9ad38560550afc8397cda_-90_N_4,93.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a02951a8-R_3480_jpg.rf.60ef8b9e04f9ad38560550afc8397cda_-90_N_4,93.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a02951a8-R_3480_jpg.rf.60ef8b9e04f9ad38560550afc8397cda_-90_horizontal_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a02951a8-R_3480_jpg.rf.60ef8b9e04f9ad38560550afc8397cda_-90_horizontal_N.txt
# Processing image: 801bda44-R_1136_jpg.rf.19622b1e2e58ebf9e5ce65b6f6507ada.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/801bda44-R_1136_jpg.rf.19622b1e2e58ebf9e5ce65b6f6507ada.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/801bda44-R_1136_jpg.rf.19622b1e2e58ebf9e5ce65b6f6507ada.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/801bda44-R_1136_jpg.rf.19622b1e2e58ebf9e5ce65b6f6507ada_-90_N_-34,03.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/801bda44-R_1136_jpg.rf.19622b1e2e58ebf9e5ce65b6f6507ada_-90_N_-34,03.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/801bda44-R_1136_jpg.rf.19622b1e2e58ebf9e5ce65b6f6507ada_N_N_37,18.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/801bda44-R_1136_jpg.rf.19622b1e2e58ebf9e5ce65b6f6507ada_N_N_37,18.txt
# Processing image: 467697c7-R_90_jpg.rf.f69d05230182904dac9040d3eb5b55d0.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/467697c7-R_90_jpg.rf.f69d05230182904dac9040d3eb5b55d0.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/467697c7-R_90_jpg.rf.f69d05230182904dac9040d3eb5b55d0.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/467697c7-R_90_jpg.rf.f69d05230182904dac9040d3eb5b55d0_90_vertical_40,63.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/467697c7-R_90_jpg.rf.f69d05230182904dac9040d3eb5b55d0_90_vertical_40,63.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/467697c7-R_90_jpg.rf.f69d05230182904dac9040d3eb5b55d0_N_vertical_-13,51.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/467697c7-R_90_jpg.rf.f69d05230182904dac9040d3eb5b55d0_N_vertical_-13,51.txt
# Processing image: a269dd4a-R_3554_jpg.rf.ec3fe82136c579b39dc7a9594d5a5161.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a269dd4a-R_3554_jpg.rf.ec3fe82136c579b39dc7a9594d5a5161.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a269dd4a-R_3554_jpg.rf.ec3fe82136c579b39dc7a9594d5a5161.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a269dd4a-R_3554_jpg.rf.ec3fe82136c579b39dc7a9594d5a5161_90_N_13,21.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a269dd4a-R_3554_jpg.rf.ec3fe82136c579b39dc7a9594d5a5161_90_N_13,21.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a269dd4a-R_3554_jpg.rf.ec3fe82136c579b39dc7a9594d5a5161_90_horizontal_19,15.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a269dd4a-R_3554_jpg.rf.ec3fe82136c579b39dc7a9594d5a5161_90_horizontal_19,15.txt
# Processing image: e4286dcf-AluCan920_jpg.rf.1209aa6b78ee255c6d008ee808d8e157.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/e4286dcf-AluCan920_jpg.rf.1209aa6b78ee255c6d008ee808d8e157.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/e4286dcf-AluCan920_jpg.rf.1209aa6b78ee255c6d008ee808d8e157.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/e4286dcf-AluCan920_jpg.rf.1209aa6b78ee255c6d008ee808d8e157_90_N_22,78.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/e4286dcf-AluCan920_jpg.rf.1209aa6b78ee255c6d008ee808d8e157_90_N_22,78.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/e4286dcf-AluCan920_jpg.rf.1209aa6b78ee255c6d008ee808d8e157_90_horizontal_3,22.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/e4286dcf-AluCan920_jpg.rf.1209aa6b78ee255c6d008ee808d8e157_90_horizontal_3,22.txt
# Processing image: 80e98208-R_1913_jpg.rf.a76567f64c34d37e8dae4944ee8dbf9e.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/80e98208-R_1913_jpg.rf.a76567f64c34d37e8dae4944ee8dbf9e.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/80e98208-R_1913_jpg.rf.a76567f64c34d37e8dae4944ee8dbf9e.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/80e98208-R_1913_jpg.rf.a76567f64c34d37e8dae4944ee8dbf9e_-90_N_33,0.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/80e98208-R_1913_jpg.rf.a76567f64c34d37e8dae4944ee8dbf9e_-90_N_33,0.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/80e98208-R_1913_jpg.rf.a76567f64c34d37e8dae4944ee8dbf9e_N_horizontal_18,22.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/80e98208-R_1913_jpg.rf.a76567f64c34d37e8dae4944ee8dbf9e_N_horizontal_18,22.txt
# Processing image: 7c3c01c8-R_1004_jpg.rf.7b8cb2ece9654c081c39025fa6e0c436.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/7c3c01c8-R_1004_jpg.rf.7b8cb2ece9654c081c39025fa6e0c436.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/7c3c01c8-R_1004_jpg.rf.7b8cb2ece9654c081c39025fa6e0c436.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/7c3c01c8-R_1004_jpg.rf.7b8cb2ece9654c081c39025fa6e0c436_180_horizontal_-9,51.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/7c3c01c8-R_1004_jpg.rf.7b8cb2ece9654c081c39025fa6e0c436_180_horizontal_-9,51.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/7c3c01c8-R_1004_jpg.rf.7b8cb2ece9654c081c39025fa6e0c436_90_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/7c3c01c8-R_1004_jpg.rf.7b8cb2ece9654c081c39025fa6e0c436_90_N_N.txt
# Processing image: 31d9ef1f-R_4187_jpg.rf.61b175f328899d605142d301aed10b41.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/31d9ef1f-R_4187_jpg.rf.61b175f328899d605142d301aed10b41.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/31d9ef1f-R_4187_jpg.rf.61b175f328899d605142d301aed10b41.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/31d9ef1f-R_4187_jpg.rf.61b175f328899d605142d301aed10b41_N_vertical_18,48.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/31d9ef1f-R_4187_jpg.rf.61b175f328899d605142d301aed10b41_N_vertical_18,48.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/31d9ef1f-R_4187_jpg.rf.61b175f328899d605142d301aed10b41_-90_N_-37,72.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/31d9ef1f-R_4187_jpg.rf.61b175f328899d605142d301aed10b41_-90_N_-37,72.txt
# Processing image: 773cb6b3-O_12676_jpg.rf.643d1b48b0f86eb756cc17cf132b4488.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/773cb6b3-O_12676_jpg.rf.643d1b48b0f86eb756cc17cf132b4488.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/773cb6b3-O_12676_jpg.rf.643d1b48b0f86eb756cc17cf132b4488.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/773cb6b3-O_12676_jpg.rf.643d1b48b0f86eb756cc17cf132b4488_-90_horizontal_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/773cb6b3-O_12676_jpg.rf.643d1b48b0f86eb756cc17cf132b4488_-90_horizontal_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/773cb6b3-O_12676_jpg.rf.643d1b48b0f86eb756cc17cf132b4488_180_vertical_-3,63.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/773cb6b3-O_12676_jpg.rf.643d1b48b0f86eb756cc17cf132b4488_180_vertical_-3,63.txt
# Processing image: a8fc01a8-R_1276_jpg.rf.50d76460fd86ae3004409021a28ba83f.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a8fc01a8-R_1276_jpg.rf.50d76460fd86ae3004409021a28ba83f.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a8fc01a8-R_1276_jpg.rf.50d76460fd86ae3004409021a28ba83f.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a8fc01a8-R_1276_jpg.rf.50d76460fd86ae3004409021a28ba83f_N_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a8fc01a8-R_1276_jpg.rf.50d76460fd86ae3004409021a28ba83f_N_vertical_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a8fc01a8-R_1276_jpg.rf.50d76460fd86ae3004409021a28ba83f_180_horizontal_-27,56.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a8fc01a8-R_1276_jpg.rf.50d76460fd86ae3004409021a28ba83f_180_horizontal_-27,56.txt
# Processing image: ba66c851-R_454_jpg.rf.e9c91f344fbd70031a4ce17c27fe7563.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/ba66c851-R_454_jpg.rf.e9c91f344fbd70031a4ce17c27fe7563.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/ba66c851-R_454_jpg.rf.e9c91f344fbd70031a4ce17c27fe7563.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/ba66c851-R_454_jpg.rf.e9c91f344fbd70031a4ce17c27fe7563_90_N_1,35.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/ba66c851-R_454_jpg.rf.e9c91f344fbd70031a4ce17c27fe7563_90_N_1,35.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/ba66c851-R_454_jpg.rf.e9c91f344fbd70031a4ce17c27fe7563_180_horizontal_-46,2.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/ba66c851-R_454_jpg.rf.e9c91f344fbd70031a4ce17c27fe7563_180_horizontal_-46,2.txt
# Processing image: e3d08d97-R_1319_jpg.rf.009faa84be31a4feb3c36c3fddffc9fc.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/e3d08d97-R_1319_jpg.rf.009faa84be31a4feb3c36c3fddffc9fc.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/e3d08d97-R_1319_jpg.rf.009faa84be31a4feb3c36c3fddffc9fc.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/e3d08d97-R_1319_jpg.rf.009faa84be31a4feb3c36c3fddffc9fc_-90_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/e3d08d97-R_1319_jpg.rf.009faa84be31a4feb3c36c3fddffc9fc_-90_N_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/e3d08d97-R_1319_jpg.rf.009faa84be31a4feb3c36c3fddffc9fc_180_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/e3d08d97-R_1319_jpg.rf.009faa84be31a4feb3c36c3fddffc9fc_180_N_N.txt
# Processing image: 13233523-R_2635_jpg.rf.00ef86aac9bfe5f2caa8df498a55766e.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/13233523-R_2635_jpg.rf.00ef86aac9bfe5f2caa8df498a55766e.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/13233523-R_2635_jpg.rf.00ef86aac9bfe5f2caa8df498a55766e.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/13233523-R_2635_jpg.rf.00ef86aac9bfe5f2caa8df498a55766e_N_N_-3,53.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/13233523-R_2635_jpg.rf.00ef86aac9bfe5f2caa8df498a55766e_N_N_-3,53.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/13233523-R_2635_jpg.rf.00ef86aac9bfe5f2caa8df498a55766e_90_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/13233523-R_2635_jpg.rf.00ef86aac9bfe5f2caa8df498a55766e_90_N_N.txt
# Processing image: 5f764632-O_12681_jpg.rf.af646ce3bc3387301122bac57b6c3515.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/5f764632-O_12681_jpg.rf.af646ce3bc3387301122bac57b6c3515.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/5f764632-O_12681_jpg.rf.af646ce3bc3387301122bac57b6c3515.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/5f764632-O_12681_jpg.rf.af646ce3bc3387301122bac57b6c3515_90_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/5f764632-O_12681_jpg.rf.af646ce3bc3387301122bac57b6c3515_90_vertical_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/5f764632-O_12681_jpg.rf.af646ce3bc3387301122bac57b6c3515_-90_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/5f764632-O_12681_jpg.rf.af646ce3bc3387301122bac57b6c3515_-90_N_N.txt
# Processing image: 4ab3bee2-R_2603_jpg.rf.ae54f4796b6cc0c7db0012d8181309c2.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/4ab3bee2-R_2603_jpg.rf.ae54f4796b6cc0c7db0012d8181309c2.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/4ab3bee2-R_2603_jpg.rf.ae54f4796b6cc0c7db0012d8181309c2.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/4ab3bee2-R_2603_jpg.rf.ae54f4796b6cc0c7db0012d8181309c2_-90_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/4ab3bee2-R_2603_jpg.rf.ae54f4796b6cc0c7db0012d8181309c2_-90_N_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/4ab3bee2-R_2603_jpg.rf.ae54f4796b6cc0c7db0012d8181309c2_180_horizontal_24,8.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/4ab3bee2-R_2603_jpg.rf.ae54f4796b6cc0c7db0012d8181309c2_180_horizontal_24,8.txt
# Processing image: 15d82173-R_351_jpg.rf.e2f955df94c3de10a518340aabb7983f.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/15d82173-R_351_jpg.rf.e2f955df94c3de10a518340aabb7983f.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/15d82173-R_351_jpg.rf.e2f955df94c3de10a518340aabb7983f.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/15d82173-R_351_jpg.rf.e2f955df94c3de10a518340aabb7983f_90_vertical_22,9.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/15d82173-R_351_jpg.rf.e2f955df94c3de10a518340aabb7983f_90_vertical_22,9.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/15d82173-R_351_jpg.rf.e2f955df94c3de10a518340aabb7983f_180_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/15d82173-R_351_jpg.rf.e2f955df94c3de10a518340aabb7983f_180_N_N.txt
# Processing image: 47d24e62-R_7261_jpg.rf.b4992dce70366b20480d7616b1a1e778.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/47d24e62-R_7261_jpg.rf.b4992dce70366b20480d7616b1a1e778.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/47d24e62-R_7261_jpg.rf.b4992dce70366b20480d7616b1a1e778.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/47d24e62-R_7261_jpg.rf.b4992dce70366b20480d7616b1a1e778_90_horizontal_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/47d24e62-R_7261_jpg.rf.b4992dce70366b20480d7616b1a1e778_90_horizontal_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/47d24e62-R_7261_jpg.rf.b4992dce70366b20480d7616b1a1e778_180_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/47d24e62-R_7261_jpg.rf.b4992dce70366b20480d7616b1a1e778_180_vertical_N.txt
# Processing image: 0690b401-AluCan195_jpg.rf.c8dab25429b70712ed2efa752c2f256c.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/0690b401-AluCan195_jpg.rf.c8dab25429b70712ed2efa752c2f256c.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/0690b401-AluCan195_jpg.rf.c8dab25429b70712ed2efa752c2f256c.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/0690b401-AluCan195_jpg.rf.c8dab25429b70712ed2efa752c2f256c_90_vertical_-10,27.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/0690b401-AluCan195_jpg.rf.c8dab25429b70712ed2efa752c2f256c_90_vertical_-10,27.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/0690b401-AluCan195_jpg.rf.c8dab25429b70712ed2efa752c2f256c_-90_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/0690b401-AluCan195_jpg.rf.c8dab25429b70712ed2efa752c2f256c_-90_N_N.txt
# Processing image: bf86ecce-AluCan729_jpg.rf.fb9e3f692226281afd8438d5318a3224.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/bf86ecce-AluCan729_jpg.rf.fb9e3f692226281afd8438d5318a3224.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/bf86ecce-AluCan729_jpg.rf.fb9e3f692226281afd8438d5318a3224.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/bf86ecce-AluCan729_jpg.rf.fb9e3f692226281afd8438d5318a3224_-90_horizontal_-49,92.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/bf86ecce-AluCan729_jpg.rf.fb9e3f692226281afd8438d5318a3224_-90_horizontal_-49,92.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/bf86ecce-AluCan729_jpg.rf.fb9e3f692226281afd8438d5318a3224_90_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/bf86ecce-AluCan729_jpg.rf.fb9e3f692226281afd8438d5318a3224_90_N_N.txt
# Processing image: 71b24ed3-O_12668_jpg.rf.798ac7a39a2aae5d2408aca92403776a.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/71b24ed3-O_12668_jpg.rf.798ac7a39a2aae5d2408aca92403776a.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/71b24ed3-O_12668_jpg.rf.798ac7a39a2aae5d2408aca92403776a.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/71b24ed3-O_12668_jpg.rf.798ac7a39a2aae5d2408aca92403776a_90_N_-23,35.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/71b24ed3-O_12668_jpg.rf.798ac7a39a2aae5d2408aca92403776a_90_N_-23,35.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/71b24ed3-O_12668_jpg.rf.798ac7a39a2aae5d2408aca92403776a_N_vertical_-44,48.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/71b24ed3-O_12668_jpg.rf.798ac7a39a2aae5d2408aca92403776a_N_vertical_-44,48.txt
# Processing image: 64b6d3f8-R_3939_jpg.rf.803810660b5dcb1eb198ef601b4cb54d.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/64b6d3f8-R_3939_jpg.rf.803810660b5dcb1eb198ef601b4cb54d.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/64b6d3f8-R_3939_jpg.rf.803810660b5dcb1eb198ef601b4cb54d.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/64b6d3f8-R_3939_jpg.rf.803810660b5dcb1eb198ef601b4cb54d_-90_vertical_25,95.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/64b6d3f8-R_3939_jpg.rf.803810660b5dcb1eb198ef601b4cb54d_-90_vertical_25,95.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/64b6d3f8-R_3939_jpg.rf.803810660b5dcb1eb198ef601b4cb54d_-90_N_-12,77.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/64b6d3f8-R_3939_jpg.rf.803810660b5dcb1eb198ef601b4cb54d_-90_N_-12,77.txt
# Processing image: 4569da64-R_3278_jpg.rf.d0f2f03d0d708cc84362a2d14c93c27e.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/4569da64-R_3278_jpg.rf.d0f2f03d0d708cc84362a2d14c93c27e.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/4569da64-R_3278_jpg.rf.d0f2f03d0d708cc84362a2d14c93c27e.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/4569da64-R_3278_jpg.rf.d0f2f03d0d708cc84362a2d14c93c27e_90_horizontal_34,93.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/4569da64-R_3278_jpg.rf.d0f2f03d0d708cc84362a2d14c93c27e_90_horizontal_34,93.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/4569da64-R_3278_jpg.rf.d0f2f03d0d708cc84362a2d14c93c27e_180_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/4569da64-R_3278_jpg.rf.d0f2f03d0d708cc84362a2d14c93c27e_180_N_N.txt
# Processing image: d88edc09-R_2538_jpg.rf.ffe2100f5b4c9ea55e32012bd3a7429a.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/d88edc09-R_2538_jpg.rf.ffe2100f5b4c9ea55e32012bd3a7429a.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/d88edc09-R_2538_jpg.rf.ffe2100f5b4c9ea55e32012bd3a7429a.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/d88edc09-R_2538_jpg.rf.ffe2100f5b4c9ea55e32012bd3a7429a_-90_vertical_1,31.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/d88edc09-R_2538_jpg.rf.ffe2100f5b4c9ea55e32012bd3a7429a_-90_vertical_1,31.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/d88edc09-R_2538_jpg.rf.ffe2100f5b4c9ea55e32012bd3a7429a_90_vertical_49,89.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/d88edc09-R_2538_jpg.rf.ffe2100f5b4c9ea55e32012bd3a7429a_90_vertical_49,89.txt
# Processing image: ba0d8b2b-R_2349_jpg.rf.00e1a9f0601479379f1823e2f61f2563.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/ba0d8b2b-R_2349_jpg.rf.00e1a9f0601479379f1823e2f61f2563.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/ba0d8b2b-R_2349_jpg.rf.00e1a9f0601479379f1823e2f61f2563.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/ba0d8b2b-R_2349_jpg.rf.00e1a9f0601479379f1823e2f61f2563_N_vertical_44,18.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/ba0d8b2b-R_2349_jpg.rf.00e1a9f0601479379f1823e2f61f2563_N_vertical_44,18.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/ba0d8b2b-R_2349_jpg.rf.00e1a9f0601479379f1823e2f61f2563_-90_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/ba0d8b2b-R_2349_jpg.rf.00e1a9f0601479379f1823e2f61f2563_-90_vertical_N.txt
# Processing image: 13ce43fe-R_1821_jpg.rf.08c7126a106a96fe11288528456c4a34.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/13ce43fe-R_1821_jpg.rf.08c7126a106a96fe11288528456c4a34.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/13ce43fe-R_1821_jpg.rf.08c7126a106a96fe11288528456c4a34.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/13ce43fe-R_1821_jpg.rf.08c7126a106a96fe11288528456c4a34_-90_vertical_16,48.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/13ce43fe-R_1821_jpg.rf.08c7126a106a96fe11288528456c4a34_-90_vertical_16,48.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/13ce43fe-R_1821_jpg.rf.08c7126a106a96fe11288528456c4a34_-90_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/13ce43fe-R_1821_jpg.rf.08c7126a106a96fe11288528456c4a34_-90_vertical_N.txt
# Processing image: 09cf75d6-O_13585_jpg.rf.33b7ca47a63a19c4d2cc710bd22448df.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/09cf75d6-O_13585_jpg.rf.33b7ca47a63a19c4d2cc710bd22448df.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/09cf75d6-O_13585_jpg.rf.33b7ca47a63a19c4d2cc710bd22448df.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/09cf75d6-O_13585_jpg.rf.33b7ca47a63a19c4d2cc710bd22448df_N_N_3,57.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/09cf75d6-O_13585_jpg.rf.33b7ca47a63a19c4d2cc710bd22448df_N_N_3,57.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/09cf75d6-O_13585_jpg.rf.33b7ca47a63a19c4d2cc710bd22448df_-90_horizontal_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/09cf75d6-O_13585_jpg.rf.33b7ca47a63a19c4d2cc710bd22448df_-90_horizontal_N.txt
# Processing image: 1030bf45-R_2682_jpg.rf.ba71b513fbda176307d098794204ba5f.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/1030bf45-R_2682_jpg.rf.ba71b513fbda176307d098794204ba5f.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/1030bf45-R_2682_jpg.rf.ba71b513fbda176307d098794204ba5f.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/1030bf45-R_2682_jpg.rf.ba71b513fbda176307d098794204ba5f_-90_N_43,6.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/1030bf45-R_2682_jpg.rf.ba71b513fbda176307d098794204ba5f_-90_N_43,6.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/1030bf45-R_2682_jpg.rf.ba71b513fbda176307d098794204ba5f_N_vertical_42,77.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/1030bf45-R_2682_jpg.rf.ba71b513fbda176307d098794204ba5f_N_vertical_42,77.txt
# Processing image: 751d0878-R_4104_jpg.rf.71d0f4384409fb041d1f92ec5300e17c.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/751d0878-R_4104_jpg.rf.71d0f4384409fb041d1f92ec5300e17c.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/751d0878-R_4104_jpg.rf.71d0f4384409fb041d1f92ec5300e17c.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/751d0878-R_4104_jpg.rf.71d0f4384409fb041d1f92ec5300e17c_N_horizontal_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/751d0878-R_4104_jpg.rf.71d0f4384409fb041d1f92ec5300e17c_N_horizontal_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/751d0878-R_4104_jpg.rf.71d0f4384409fb041d1f92ec5300e17c_-90_horizontal_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/751d0878-R_4104_jpg.rf.71d0f4384409fb041d1f92ec5300e17c_-90_horizontal_N.txt
# Processing image: 460e4845-AluCan234_jpg.rf.6826fe3a8e39e00175eb4315598a8c2b.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/460e4845-AluCan234_jpg.rf.6826fe3a8e39e00175eb4315598a8c2b.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/460e4845-AluCan234_jpg.rf.6826fe3a8e39e00175eb4315598a8c2b.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/460e4845-AluCan234_jpg.rf.6826fe3a8e39e00175eb4315598a8c2b_N_vertical_-0,71.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/460e4845-AluCan234_jpg.rf.6826fe3a8e39e00175eb4315598a8c2b_N_vertical_-0,71.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/460e4845-AluCan234_jpg.rf.6826fe3a8e39e00175eb4315598a8c2b_-90_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/460e4845-AluCan234_jpg.rf.6826fe3a8e39e00175eb4315598a8c2b_-90_vertical_N.txt
# Processing image: 39d1e3d6-R_2028_jpg.rf.bc9f46ec205f2f482791b9731f51975a.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/39d1e3d6-R_2028_jpg.rf.bc9f46ec205f2f482791b9731f51975a.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/39d1e3d6-R_2028_jpg.rf.bc9f46ec205f2f482791b9731f51975a.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/39d1e3d6-R_2028_jpg.rf.bc9f46ec205f2f482791b9731f51975a_-90_horizontal_35,07.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/39d1e3d6-R_2028_jpg.rf.bc9f46ec205f2f482791b9731f51975a_-90_horizontal_35,07.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/39d1e3d6-R_2028_jpg.rf.bc9f46ec205f2f482791b9731f51975a_-90_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/39d1e3d6-R_2028_jpg.rf.bc9f46ec205f2f482791b9731f51975a_-90_vertical_N.txt
# Processing image: 16bc7750-O_13899_jpg.rf.5b8c9645bfb9916fe6f09d4e73710a17.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/16bc7750-O_13899_jpg.rf.5b8c9645bfb9916fe6f09d4e73710a17.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/16bc7750-O_13899_jpg.rf.5b8c9645bfb9916fe6f09d4e73710a17.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/16bc7750-O_13899_jpg.rf.5b8c9645bfb9916fe6f09d4e73710a17_N_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/16bc7750-O_13899_jpg.rf.5b8c9645bfb9916fe6f09d4e73710a17_N_vertical_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/16bc7750-O_13899_jpg.rf.5b8c9645bfb9916fe6f09d4e73710a17_90_vertical_48,8.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/16bc7750-O_13899_jpg.rf.5b8c9645bfb9916fe6f09d4e73710a17_90_vertical_48,8.txt
# Processing image: a00113de-O_12645_jpg.rf.27239911044292b0543715be15520651.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a00113de-O_12645_jpg.rf.27239911044292b0543715be15520651.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a00113de-O_12645_jpg.rf.27239911044292b0543715be15520651.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a00113de-O_12645_jpg.rf.27239911044292b0543715be15520651_90_N_-14,59.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a00113de-O_12645_jpg.rf.27239911044292b0543715be15520651_90_N_-14,59.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/a00113de-O_12645_jpg.rf.27239911044292b0543715be15520651_N_horizontal_-37,84.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/a00113de-O_12645_jpg.rf.27239911044292b0543715be15520651_N_horizontal_-37,84.txt
# Processing image: fdc43003-R_2918_jpg.rf.e83013271e3473c96214fd59c6c7d339.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/fdc43003-R_2918_jpg.rf.e83013271e3473c96214fd59c6c7d339.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/fdc43003-R_2918_jpg.rf.e83013271e3473c96214fd59c6c7d339.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/fdc43003-R_2918_jpg.rf.e83013271e3473c96214fd59c6c7d339_90_horizontal_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/fdc43003-R_2918_jpg.rf.e83013271e3473c96214fd59c6c7d339_90_horizontal_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/fdc43003-R_2918_jpg.rf.e83013271e3473c96214fd59c6c7d339_180_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/fdc43003-R_2918_jpg.rf.e83013271e3473c96214fd59c6c7d339_180_N_N.txt
# Processing image: 3a597489-R_4308_jpg.rf.c74d57c4b0ab8996d500676d74de43d7.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/3a597489-R_4308_jpg.rf.c74d57c4b0ab8996d500676d74de43d7.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/3a597489-R_4308_jpg.rf.c74d57c4b0ab8996d500676d74de43d7.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/3a597489-R_4308_jpg.rf.c74d57c4b0ab8996d500676d74de43d7_180_N_25,89.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/3a597489-R_4308_jpg.rf.c74d57c4b0ab8996d500676d74de43d7_180_N_25,89.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/3a597489-R_4308_jpg.rf.c74d57c4b0ab8996d500676d74de43d7_180_horizontal_-18,27.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/3a597489-R_4308_jpg.rf.c74d57c4b0ab8996d500676d74de43d7_180_horizontal_-18,27.txt
# Processing image: 95944675-R_783_jpg.rf.b40f598309536acaa4b8e982dc620ad5.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/95944675-R_783_jpg.rf.b40f598309536acaa4b8e982dc620ad5.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/95944675-R_783_jpg.rf.b40f598309536acaa4b8e982dc620ad5.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/95944675-R_783_jpg.rf.b40f598309536acaa4b8e982dc620ad5_N_horizontal_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/95944675-R_783_jpg.rf.b40f598309536acaa4b8e982dc620ad5_N_horizontal_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/95944675-R_783_jpg.rf.b40f598309536acaa4b8e982dc620ad5_90_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/95944675-R_783_jpg.rf.b40f598309536acaa4b8e982dc620ad5_90_N_N.txt
# Processing image: 042543f0-R_3838_jpg.rf.a53f535dc6165fc85862eae16acf4295.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/042543f0-R_3838_jpg.rf.a53f535dc6165fc85862eae16acf4295.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/042543f0-R_3838_jpg.rf.a53f535dc6165fc85862eae16acf4295.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/042543f0-R_3838_jpg.rf.a53f535dc6165fc85862eae16acf4295_180_N_2,37.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/042543f0-R_3838_jpg.rf.a53f535dc6165fc85862eae16acf4295_180_N_2,37.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/042543f0-R_3838_jpg.rf.a53f535dc6165fc85862eae16acf4295_90_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/042543f0-R_3838_jpg.rf.a53f535dc6165fc85862eae16acf4295_90_N_N.txt
# Processing image: 2d456d31-R_1830_jpg.rf.d33f3f10a6be6548c617d096c7e9e0f0.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/2d456d31-R_1830_jpg.rf.d33f3f10a6be6548c617d096c7e9e0f0.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/2d456d31-R_1830_jpg.rf.d33f3f10a6be6548c617d096c7e9e0f0.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/2d456d31-R_1830_jpg.rf.d33f3f10a6be6548c617d096c7e9e0f0_-90_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/2d456d31-R_1830_jpg.rf.d33f3f10a6be6548c617d096c7e9e0f0_-90_vertical_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/2d456d31-R_1830_jpg.rf.d33f3f10a6be6548c617d096c7e9e0f0_180_vertical_19,36.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/2d456d31-R_1830_jpg.rf.d33f3f10a6be6548c617d096c7e9e0f0_180_vertical_19,36.txt
# Processing image: b5572b13-O_13950_jpg.rf.51ba49f394e03d00375fd366a1231e93.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/b5572b13-O_13950_jpg.rf.51ba49f394e03d00375fd366a1231e93.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/b5572b13-O_13950_jpg.rf.51ba49f394e03d00375fd366a1231e93.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/b5572b13-O_13950_jpg.rf.51ba49f394e03d00375fd366a1231e93_180_horizontal_9,81.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/b5572b13-O_13950_jpg.rf.51ba49f394e03d00375fd366a1231e93_180_horizontal_9,81.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/b5572b13-O_13950_jpg.rf.51ba49f394e03d00375fd366a1231e93_N_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/b5572b13-O_13950_jpg.rf.51ba49f394e03d00375fd366a1231e93_N_vertical_N.txt
# Processing image: b9202cc9-O_13658_jpg.rf.1c1d81bb29528bad8b7f133b14575ffe.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/b9202cc9-O_13658_jpg.rf.1c1d81bb29528bad8b7f133b14575ffe.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/b9202cc9-O_13658_jpg.rf.1c1d81bb29528bad8b7f133b14575ffe.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/b9202cc9-O_13658_jpg.rf.1c1d81bb29528bad8b7f133b14575ffe_180_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/b9202cc9-O_13658_jpg.rf.1c1d81bb29528bad8b7f133b14575ffe_180_vertical_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/b9202cc9-O_13658_jpg.rf.1c1d81bb29528bad8b7f133b14575ffe_90_horizontal_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/b9202cc9-O_13658_jpg.rf.1c1d81bb29528bad8b7f133b14575ffe_90_horizontal_N.txt
# Processing image: ddee6c47-AluCan837_jpg.rf.a9339b7243672c4212ba49570e21339a.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/ddee6c47-AluCan837_jpg.rf.a9339b7243672c4212ba49570e21339a.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/ddee6c47-AluCan837_jpg.rf.a9339b7243672c4212ba49570e21339a.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/ddee6c47-AluCan837_jpg.rf.a9339b7243672c4212ba49570e21339a_-90_horizontal_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/ddee6c47-AluCan837_jpg.rf.a9339b7243672c4212ba49570e21339a_-90_horizontal_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/ddee6c47-AluCan837_jpg.rf.a9339b7243672c4212ba49570e21339a_180_N_-19,17.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/ddee6c47-AluCan837_jpg.rf.a9339b7243672c4212ba49570e21339a_180_N_-19,17.txt
# Processing image: b30a5281-R_403_jpg.rf.9c09058cc49787a9de8539c6a497ae61.jpg
# ...
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/c731127b-R_2645_jpg.rf.a27412325d3cf301934b86eff7932450_N_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/c731127b-R_2645_jpg.rf.a27412325d3cf301934b86eff7932450_N_vertical_N.txt
# Processing image: 89f55dd9-R_53_jpg.rf.e8eb7acc8c48b2a45591df9126f33388.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/89f55dd9-R_53_jpg.rf.e8eb7acc8c48b2a45591df9126f33388.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/89f55dd9-R_53_jpg.rf.e8eb7acc8c48b2a45591df9126f33388.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/89f55dd9-R_53_jpg.rf.e8eb7acc8c48b2a45591df9126f33388_-90_horizontal_7,55.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/89f55dd9-R_53_jpg.rf.e8eb7acc8c48b2a45591df9126f33388_-90_horizontal_7,55.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/89f55dd9-R_53_jpg.rf.e8eb7acc8c48b2a45591df9126f33388_-90_horizontal_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/89f55dd9-R_53_jpg.rf.e8eb7acc8c48b2a45591df9126f33388_-90_horizontal_N.txt
# Processing image: 81c9f73f-R_297_jpg.rf.cb0895e69a0fd1aa16706b7cb4cb2fdd.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/81c9f73f-R_297_jpg.rf.cb0895e69a0fd1aa16706b7cb4cb2fdd.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/81c9f73f-R_297_jpg.rf.cb0895e69a0fd1aa16706b7cb4cb2fdd.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/81c9f73f-R_297_jpg.rf.cb0895e69a0fd1aa16706b7cb4cb2fdd_90_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/81c9f73f-R_297_jpg.rf.cb0895e69a0fd1aa16706b7cb4cb2fdd_90_N_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/81c9f73f-R_297_jpg.rf.cb0895e69a0fd1aa16706b7cb4cb2fdd_180_horizontal_16,73.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/81c9f73f-R_297_jpg.rf.cb0895e69a0fd1aa16706b7cb4cb2fdd_180_horizontal_16,73.txt
# Processing image: fec76d2d-O_13604_jpg.rf.8b9691d1851b41b767aff98685ab7316.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/fec76d2d-O_13604_jpg.rf.8b9691d1851b41b767aff98685ab7316.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/fec76d2d-O_13604_jpg.rf.8b9691d1851b41b767aff98685ab7316.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/fec76d2d-O_13604_jpg.rf.8b9691d1851b41b767aff98685ab7316_180_N_-39,15.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/fec76d2d-O_13604_jpg.rf.8b9691d1851b41b767aff98685ab7316_180_N_-39,15.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/fec76d2d-O_13604_jpg.rf.8b9691d1851b41b767aff98685ab7316_N_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/fec76d2d-O_13604_jpg.rf.8b9691d1851b41b767aff98685ab7316_N_vertical_N.txt
# Processing image: dae27e2b-O_12580_jpg.rf.5fd518ed2bb1904615180b2df585673c.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/dae27e2b-O_12580_jpg.rf.5fd518ed2bb1904615180b2df585673c.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/dae27e2b-O_12580_jpg.rf.5fd518ed2bb1904615180b2df585673c.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/dae27e2b-O_12580_jpg.rf.5fd518ed2bb1904615180b2df585673c_180_horizontal_-42,98.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/dae27e2b-O_12580_jpg.rf.5fd518ed2bb1904615180b2df585673c_180_horizontal_-42,98.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/dae27e2b-O_12580_jpg.rf.5fd518ed2bb1904615180b2df585673c_180_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/dae27e2b-O_12580_jpg.rf.5fd518ed2bb1904615180b2df585673c_180_vertical_N.txt
# Processing image: e658e857-AluCan714_jpg.rf.1b5dd9379a716b0c17a1bba31833a322.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/e658e857-AluCan714_jpg.rf.1b5dd9379a716b0c17a1bba31833a322.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/e658e857-AluCan714_jpg.rf.1b5dd9379a716b0c17a1bba31833a322.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/e658e857-AluCan714_jpg.rf.1b5dd9379a716b0c17a1bba31833a322_N_vertical_19,08.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/e658e857-AluCan714_jpg.rf.1b5dd9379a716b0c17a1bba31833a322_N_vertical_19,08.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/e658e857-AluCan714_jpg.rf.1b5dd9379a716b0c17a1bba31833a322_180_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/e658e857-AluCan714_jpg.rf.1b5dd9379a716b0c17a1bba31833a322_180_N_N.txt
# Processing image: 2a4fecb0-R_2647_jpg.rf.3f43b967149b3329dbbf1577a78699b8.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/2a4fecb0-R_2647_jpg.rf.3f43b967149b3329dbbf1577a78699b8.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/2a4fecb0-R_2647_jpg.rf.3f43b967149b3329dbbf1577a78699b8.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/2a4fecb0-R_2647_jpg.rf.3f43b967149b3329dbbf1577a78699b8_90_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/2a4fecb0-R_2647_jpg.rf.3f43b967149b3329dbbf1577a78699b8_90_N_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/2a4fecb0-R_2647_jpg.rf.3f43b967149b3329dbbf1577a78699b8_-90_N_-40,41.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/2a4fecb0-R_2647_jpg.rf.3f43b967149b3329dbbf1577a78699b8_-90_N_-40,41.txt
# Processing image: ff9aaca0-R_4003_jpg.rf.4db1ac580ad11110d48024706eab6188.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/ff9aaca0-R_4003_jpg.rf.4db1ac580ad11110d48024706eab6188.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/ff9aaca0-R_4003_jpg.rf.4db1ac580ad11110d48024706eab6188.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/ff9aaca0-R_4003_jpg.rf.4db1ac580ad11110d48024706eab6188_N_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/ff9aaca0-R_4003_jpg.rf.4db1ac580ad11110d48024706eab6188_N_vertical_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/ff9aaca0-R_4003_jpg.rf.4db1ac580ad11110d48024706eab6188_N_horizontal_15,1.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/ff9aaca0-R_4003_jpg.rf.4db1ac580ad11110d48024706eab6188_N_horizontal_15,1.txt
# Processing image: 668e4750-R_2872_jpg.rf.34fca7620663bbaaf6076cd2a7d6d201.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/668e4750-R_2872_jpg.rf.34fca7620663bbaaf6076cd2a7d6d201.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/668e4750-R_2872_jpg.rf.34fca7620663bbaaf6076cd2a7d6d201.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/668e4750-R_2872_jpg.rf.34fca7620663bbaaf6076cd2a7d6d201_90_N_-35,9.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/668e4750-R_2872_jpg.rf.34fca7620663bbaaf6076cd2a7d6d201_90_N_-35,9.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/668e4750-R_2872_jpg.rf.34fca7620663bbaaf6076cd2a7d6d201_-90_N_-18,1.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/668e4750-R_2872_jpg.rf.34fca7620663bbaaf6076cd2a7d6d201_-90_N_-18,1.txt
# Processing image: 5987db3e-R_2781_jpg.rf.c8406d7aabcfbc35e79eb40b74d73239.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/5987db3e-R_2781_jpg.rf.c8406d7aabcfbc35e79eb40b74d73239.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/5987db3e-R_2781_jpg.rf.c8406d7aabcfbc35e79eb40b74d73239.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/5987db3e-R_2781_jpg.rf.c8406d7aabcfbc35e79eb40b74d73239_-90_vertical_16,31.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/5987db3e-R_2781_jpg.rf.c8406d7aabcfbc35e79eb40b74d73239_-90_vertical_16,31.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/5987db3e-R_2781_jpg.rf.c8406d7aabcfbc35e79eb40b74d73239_90_vertical_-28,86.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/5987db3e-R_2781_jpg.rf.c8406d7aabcfbc35e79eb40b74d73239_90_vertical_-28,86.txt
# Processing image: 6fb76107-O_13921_jpg.rf.61719bfe6f552372564ce824bbff10f5.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/6fb76107-O_13921_jpg.rf.61719bfe6f552372564ce824bbff10f5.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/6fb76107-O_13921_jpg.rf.61719bfe6f552372564ce824bbff10f5.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/6fb76107-O_13921_jpg.rf.61719bfe6f552372564ce824bbff10f5_-90_N_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/6fb76107-O_13921_jpg.rf.61719bfe6f552372564ce824bbff10f5_-90_N_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/6fb76107-O_13921_jpg.rf.61719bfe6f552372564ce824bbff10f5_-90_N_27,22.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/6fb76107-O_13921_jpg.rf.61719bfe6f552372564ce824bbff10f5_-90_N_27,22.txt
# Processing image: 5904eebf-R_501_jpg.rf.528138d9e9c3a714c702ba3763c35a40.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/5904eebf-R_501_jpg.rf.528138d9e9c3a714c702ba3763c35a40.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/5904eebf-R_501_jpg.rf.528138d9e9c3a714c702ba3763c35a40.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/5904eebf-R_501_jpg.rf.528138d9e9c3a714c702ba3763c35a40_180_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/5904eebf-R_501_jpg.rf.528138d9e9c3a714c702ba3763c35a40_180_vertical_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/5904eebf-R_501_jpg.rf.528138d9e9c3a714c702ba3763c35a40_-90_N_18,31.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/5904eebf-R_501_jpg.rf.528138d9e9c3a714c702ba3763c35a40_-90_N_18,31.txt
# Processing image: 804a17c8-R_1232_jpg.rf.46ce06facc7b1c2eb621896f4a72365b.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/804a17c8-R_1232_jpg.rf.46ce06facc7b1c2eb621896f4a72365b.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/804a17c8-R_1232_jpg.rf.46ce06facc7b1c2eb621896f4a72365b.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/804a17c8-R_1232_jpg.rf.46ce06facc7b1c2eb621896f4a72365b_180_vertical_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/804a17c8-R_1232_jpg.rf.46ce06facc7b1c2eb621896f4a72365b_180_vertical_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/804a17c8-R_1232_jpg.rf.46ce06facc7b1c2eb621896f4a72365b_-90_N_-6,79.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/804a17c8-R_1232_jpg.rf.46ce06facc7b1c2eb621896f4a72365b_-90_N_-6,79.txt
# Processing image: 723919d6-R_8069_jpg.rf.ffe5978f9eeea5ece060aca84591eb42.jpg
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/723919d6-R_8069_jpg.rf.ffe5978f9eeea5ece060aca84591eb42.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/723919d6-R_8069_jpg.rf.ffe5978f9eeea5ece060aca84591eb42.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/723919d6-R_8069_jpg.rf.ffe5978f9eeea5ece060aca84591eb42_180_horizontal_N.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/723919d6-R_8069_jpg.rf.ffe5978f9eeea5ece060aca84591eb42_180_horizontal_N.txt
# Transformed image saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/images/723919d6-R_8069_jpg.rf.ffe5978f9eeea5ece060aca84591eb42.jpg
# Transformed annotations saved as: ../../datasets/extracted/RoboFlow-2-augmented/train/labels/723919d6-R_8069_jpg.rf.ffe5978f9eeea5ece060aca84591eb42.txt
# Processing image: a5f85583-AluCan103_jpg.rf.32b4053173b26cb640dfd5ae411a78c4.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [44], line 19
#      17 if image_name.endswith('.jpg'):
#      18     print(f"Processing image: {image_name}")
# ---> 19     load_transform_store(src_dir, image_name, out_dir)
#      20 else:
#      21     print(f"Skipping non-image file: {image_name}")
#
# Cell In [42], line 186, in load_transform_store(src_dir, image_name, out_dir)
#     183     annotations = [tuple(map(float, line.strip().split()[:5])) for line in f.readlines()]
#     185 # Transform the image and annotations
# --> 186 output = transform_image(image, annotations)
#     188 # Store the results
#     189 for i, (final_image, final_annotations, transformation) in enumerate(zip(output['images'], output['annotations'], output['transformations'])):
#     190     # Save the image
#
# Cell In [42], line 129, in transform_image(image, annotations)
#     126 pixels = PIXELS
#     128 # Add the original image and annotations resized
# --> 129 resized_image = resize_image(image, pixels)
#     130 resized_annotations = resize_annotations(image, annotations, pixels)
#     131 output['images'].append(resized_image)
#
# Cell In [42], line 7, in resize_image(image, pixels)
#       6 def resize_image(image, pixels):
# ----> 7     return image.resize((pixels, pixels))
#
# File ~/ProgramFiles/anaconda3/envs/IS_AY2425/lib/python3.8/site-packages/PIL/Image.py:2328, in Image.resize(self, size, resample, box, reducing_gap)
#    2316         self = (
#    2317             self.reduce(factor, box=reduce_box)
#    2318             if callable(self.reduce)
#    2319             else Image.reduce(self, factor, box=reduce_box)
#    2320         )
#    2321         box = (
#    2322             (box[0] - reduce_box[0]) / factor_x,
#    2323             (box[1] - reduce_box[1]) / factor_y,
#    2324             (box[2] - reduce_box[0]) / factor_x,
#    2325             (box[3] - reduce_box[1]) / factor_y,
#    2326         )
# -> 2328 return self._new(self.im.resize(size, resample, box))
#
# KeyboardInterrupt:
